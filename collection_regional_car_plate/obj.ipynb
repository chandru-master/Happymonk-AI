# %%
import tensorflow as tf

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# 'c:\\Users\\CHANDRU MASTER\\Desktop\\train__data\\images'

# %%
img = image.load_img("C://Users//CHANDRU MASTER//Desktop//train__data//images//train//01313 (1).jpg")

# %%
plt.imshow(img)

# %%
cv2.imread("C://Users//CHANDRU MASTER//Desktop//train__data//images//train//01313 (1).jpg").shape
# Out:
# (2048, 1536, 3)

# %%
cv2.imread("C://Users//CHANDRU MASTER//Desktop//train__data//images//train//01313 (1).jpg")
# Out:
# array([[[  0,   0, 113],
#         [  0,   1, 114],
#         [  2,   5, 114],
#         ...,
#         [ 15,  23,  70],
#         [ 15,  24,  68],
#         [ 14,  23,  67]],
#
#        [[  0,   0, 112],
#         [  0,   0, 113],
#         [  0,   3, 112],
#         ...,
#         [ 14,  22,  69],
#         [ 13,  22,  66],
#         [ 13,  22,  66]],
#
#        [[  0,   1, 114],
#         [  0,   1, 113],
#         [  2,   5, 113],
#         ...,
#         [ 16,  24,  71],
#         [ 17,  26,  70],
#         [ 17,  26,  70]],
#
#        ...,
#
#        [[  0,   6,   0],
#         [  1,   9,   2],
#         [  3,  11,   4],
#         ...,
#         [ 11,  18,  15],
#         [ 11,  18,  15],
#         [ 11,  18,  15]],
#
#        [[  0,   7,   0],
#         [  0,   7,   0],
#         [  0,   8,   1],
#         ...,
#         [ 14,  21,  18],
#         [ 14,  21,  18],
#         [ 13,  20,  17]],
#
#        [[  2,  10,   3],
#         [  0,   7,   0],
#         [  0,   6,   0],
# ...

# %%
train = ImageDataGenerator(rescale=1/255)
validation = ImageDataGenerator(rescale=1/255)

# %%
train_dataset = train.flow_from_directory("C://Users//CHANDRU MASTER//Desktop//train__data//images//train//",
                                          target_size=(200,200),
                                          batch_size=1,
                                          class_mode= "binary")

validation_dataset = validation.flow_from_directory("C://Users//CHANDRU MASTER//Desktop//train__data//images//val//",
                                          target_size=(200,200),
                                          batch_size=1,
                                          class_mode= "binary")
# Out:
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
